# %%
import pandas as pd
import spacy
from spacy.language import Language
from spacy_langdetect import LanguageDetector
from sklearn.cluster import KMeans
import helpers
import pickle
import pathlib
# Out:
# Using Russia server backend.

# %%
wish_list_df = pd.read_csv('data/db/wish_lists.csv')
wish_list_df = wish_list_df[['id', 'title']]
print('wish lists:', len(wish_list_df))

wish_list_df.head()
# Out:
# wish lists: 2405
#                          id         title
# 0  d461b35a519d8af010947904  For the soul
# 1  cd5fae468ca89c6478416068      Для дома
# 2  5c5fc79ce81a1a1030838078  👶🏻 Для детей
# 3  945fdb57abc3e52529717750        Шмотки
# 4  505fc79cdff2233891049727      📱Техника

# %%
w_titles = wish_list_df['title'].to_list()
wish_list_df['new_title'] = [helpers.clear_text(title) for title in w_titles]
wish_list_df.head()
# Out:
#                          id         title     new_title
# 0  d461b35a519d8af010947904  For the soul  for the soul
# 1  cd5fae468ca89c6478416068      Для дома      для дома
# 2  5c5fc79ce81a1a1030838078  👶🏻 Для детей     для детей
# 3  945fdb57abc3e52529717750        Шмотки        шмотки
# 4  505fc79cdff2233891049727      📱Техника       техника

# %%
def get_lang_detector(nlp, name):
    return LanguageDetector()


lang_nlp = spacy.load("en_core_web_sm")
Language.factory("language_detector", func=get_lang_detector)
lang_nlp.add_pipe('language_detector', last=True)

# %%
langs = []
for title in w_titles:
    doc = lang_nlp(title)
    langs.append(doc._.language['language'])

wish_list_df['lang'] = langs
wish_list_df.head()
# Out:
#                          id         title     new_title lang
# 0  d461b35a519d8af010947904  For the soul  for the soul   en
# 1  cd5fae468ca89c6478416068      Для дома      для дома   uk
# 2  5c5fc79ce81a1a1030838078  👶🏻 Для детей     для детей   ru
# 3  945fdb57abc3e52529717750        Шмотки        шмотки   mk
# 4  505fc79cdff2233891049727      📱Техника       техника   ru

# %%
print('all wishes:', len(wish_list_df))
wish_list_df = wish_list_df[wish_list_df['new_title'] != '']
print('filtered:', len(wish_list_df))
# Out:
# all wishes: 2405
# filtered: 2347

# %%
need_translation = True

translations_file = 'data/result/translations.pkl'
my_file = pathlib.Path(translations_file)
if my_file.is_file():
    with open(translations_file, 'rb') as f:
        translations = pickle.load(f)
    need_translation = False

need_translation = True
if need_translation:
    to_translate = wish_list_df[~wish_list_df['lang'].isin(['ru', 'UNKNOWN'])]['new_title'].unique()
    print('Titles to translate:', len(to_translate))
    print(to_translate[:3])

    translations = {}
    for i, title in enumerate(to_translate):
        russian_text = helpers.ru_text(title)
        translations[title] = russian_text
        if i % 50 == 0:
            print(f'{i} wishlist translated')

    with open(translations_file, 'wb') as f:
        pickle.dump(translations, f)
    print(f'translations are saved to {translations_file}')

else:
    print(f'translations are loaded from {translations_file}')
# Out:
# Titles to translate: 646
# ['for the soul' 'для дома' 'шмотки']
# 0 wishlist translated
# 50 wishlist translated
# 100 wishlist translated
# 150 wishlist translated
# 200 wishlist translated
# 250 wishlist translated
# 300 wishlist translated
# 350 wishlist translated
# 400 wishlist translated
# 450 wishlist translated
# 500 wishlist translated
# 550 wishlist translated
# 600 wishlist translated
# translations are saved to data/result/translations.pkl

# %%
def get_ru_text(row):
    if row['lang'] in ['ru', 'UNKNOWN']:
        return row['new_title']
    else:
        new_title = translations[row['new_title']]
        return new_title.strip().lower()

wish_list_df['ru_title'] = wish_list_df.apply(lambda row: get_ru_text(row), axis=1)
wish_list_df.head()
# Out:
#                          id         title     new_title lang   ru_title
# 0  d461b35a519d8af010947904  For the soul  for the soul   en   для души
# 1  cd5fae468ca89c6478416068      Для дома      для дома   uk   для дома
# 2  5c5fc79ce81a1a1030838078  👶🏻 Для детей     для детей   ru  для детей
# 3  945fdb57abc3e52529717750        Шмотки        шмотки   mk     шмотки
# 4  505fc79cdff2233891049727      📱Техника       техника   ru    техника

# %%
nlp = spacy.load('ru_core_news_md')

stop_words = {'подарки', 'подарок', 'подарить', 'подарочки', 'список',
              'всякий', 'другим', 'других', 'желание', 'пожелание', 'надо',
              'очень', 'хочу', 'хотеть', 'хотеться', 'нг', 'др',
              'день рождение', 'любой', 'идея', 'виш', 'прочие', 'прочая',
              'вишлист', 'виш лист', 'разное', 'хороший', 'желания', 'идея',
              'новогодний', 'тест', 'test', 'zz', 'zzz', 'yyy', 'ы', 'a',
              'купить', 'покупка', 'продать', 'покупать', 'вишлистик',
              'получить', 'всегда', 'tmp'}
nlp.Defaults.stop_words |= stop_words

ru_names = pd.read_json('data/names_table.jsonl', lines=True)
names = sorted(ru_names['text'])
names = [name.lower() for name in names]

print('ru model is loaded')
# Out:
# ru model is loaded

# %%
wish_list_df['new'] = wish_list_df.apply(lambda row: helpers.wishlist_text(nlp, row['ru_title'], names), axis=1)
wish_list_df.head()
# Out:
#                          id         title     new_title lang   ru_title  \
# 0  d461b35a519d8af010947904  For the soul  for the soul   en   для души
# 1  cd5fae468ca89c6478416068      Для дома      для дома   uk   для дома
# 2  5c5fc79ce81a1a1030838078  👶🏻 Для детей     для детей   ru  для детей
# 3  945fdb57abc3e52529717750        Шмотки        шмотки   mk     шмотки
# 4  505fc79cdff2233891049727      📱Техника       техника   ru    техника
#
#        new
# 0     душа
# 1      дом
# 2  ребёнок
# 3   шмотки
# 4  техника

# %%
wish_list_df = wish_list_df[['id', 'title', 'lang', 'new']]
file_to_save = 'data/result/new_wishlists.csv'
wish_list_df.to_csv(file_to_save)
print(f'wishlists are saved to {file_to_save}')

wish_list_df.head()
# Out:
# wishlists are saved to data/result/new_wishlists.csv
#                          id         title lang      new
# 0  d461b35a519d8af010947904  For the soul   en     душа
# 1  cd5fae468ca89c6478416068      Для дома   uk      дом
# 2  5c5fc79ce81a1a1030838078  👶🏻 Для детей   ru  ребёнок
# 3  945fdb57abc3e52529717750        Шмотки   mk   шмотки
# 4  505fc79cdff2233891049727      📱Техника   ru  техника

# %%
titles = wish_list_df[wish_list_df['new'] != '']['new'].unique()
wish_list_vecs = [nlp(wish_list).vector for wish_list in titles]
print('vectors are ready')
# Out:
# vectors are ready

# %%
cluster_wishlists = pd.DataFrame({'title': titles})
cluster_count = 100
kmeans = KMeans(n_clusters=cluster_count, random_state=0).fit(wish_list_vecs)
cluster_wishlists['label'] = kmeans.labels_

cluster_wishlists.head()
# Out:
#      title  label
# 0     душа      1
# 1      дом      1
# 2  ребёнок     42
# 3   шмотки      4
# 4  техника     87

# %%
for i in range(cluster_count):
    cluster_wish_lists = cluster_wishlists[cluster_wishlists['label'] == i]['title'].to_list()
    label_count = len(cluster_wish_lists)
    print(f'Label {i}: {label_count} wish lists')
    for wishlist in cluster_wish_lists:
        print(wishlist)
    print('\n\n')
# Out:
# Label 0: 2 wish lists
# эко
# ик
#
#
#
# Label 1: 40 wish lists
# душа
# дом
# новый
# ходить
# делать
# другое
# большой
# цель
# любить любить
# дело
# момент
# место
# муж
# первый
# комната
# семья
# друг
# новый дом
# почти тридцать
# домой
# случай
# семья дом
# мечтать
# двигаться
# скорее цель
# а
# знать
# час
# будущее
# иметь
# про
# просто
# место где побывать
# можно
# прочее
# видеть
# семья друг
# первый дело
# лицо
# новый жизнь
#
#
#
# Label 2: 204 wish lists
# хирургичка
# 3000 ₽
# деревообрабатывание
# < 1500
# тестовый задание
# настолки
# нехудожественный литература
# палитта
# плакать техно
# медсестра
# хотелки
# устройство
# pandora
# чашка
# животное
# g.a.s
# андреши
# $ $ $
# хочушки
# шуга дэддь
# сладкий 24
# хуйня собачий
# кататься конёк
# дом досуг
# < 8000
# мнемнемне
# масоки
# электроника
# космос
# косплей
# посетить
# вовке
# любы
# 34-й
# обустройство дом
# хватать
# аниме
# 12.12
# нашпщрпшпон изд группа лит рот
# даааам
# general хотелки
# ювелирка
# алёне
# марка
# дэрэ
# пашуле годик
# главный
# нога
# т.п
# кросовки
# уют
# фандомный мерч
# запрещенка
# папе
# 10 000 ₽
# кируша
# aliexpress
# 10к
# гггс
# фотосъёмка
# аромат
# 10 +
# wishlist косметос
# кицы
# босой
# cacki
# слипнуться
# вихи
# рассортировать
# родьь
# допы настолкам
# счастливый 30
# макары
# 25-летие
# импульс
# бьюти хуюти
# nnnnao
# hema
# быт
# видеоигра
# богдашке
# кондитерка
# хочеца
# ромы
# пипчика
# желатель 11_2020
# лизать
# сассант
# дорсал
# без капля стеснение
# мейкуп
# хочушечки
# предподчительнее
# 25.01.22
# счастливый 20
# компьютер
# 2021 2022
# деней вдвоем
# музло
# n.
# богатый
# лан серьезке
# seonghwa
# секретный санта
# офтальмо
# чикса
# танилово
# доминика
# блеск
# дорого мечтатьневредно
# курс макияж начинать
# bsbdnd
# хэппиздуй
# нужный
# лизализа
# тайный санты
# гора
# обучалово
# нгэшечка
# формочка печенек
# zakharia dr wineslist
# nambe van
# namba tu
# мч
# вайбы
# shein
# wildberries
# ny 4 друг
# днюше4ка
# настолочки
# варькины
# забота
# гиковая тема
# шмукс
# кроссовочки
# русланский
# больший
# инночки
# хочудилдо
# одёёёжа
# годовасие
# потанцевать
# nnn
# ебать дорого
# манга цма
# list1
# близким
# leta
# швейка
# собака
# отель kis
# 2022 мышь 5 год
# худ.материалы
# ирчику 25
# технология
# jwrl
# ненаправленный
# мя
# дуновение странность
# имамбариум
# $ $
# $
# член
# 14.02 08.03
# джуэлри
# доктор 2022
# 𝒿𝑒𝓌𝑒𝓁𝓁𝑒𝓇𝓎
# 𝒸𝓁𝑜𝓉𝒽𝑒𝓈 ️
# milanusek
# предосудительный удовольствие
# hhh
# письмо 1
# обёртка
# киттаб
# шакиры
# виталине
# хотелочки
# дорого богато
# чебурекинс
# дар
# больший хотелки
# банк открытие
# hb'25
# грабли
# желать
# хочухи
# trydzat p'yat
# сертификат золотой летуаль
# 21-й
# 700р-2000р
# 200р-700р
# 2000р 3000р
# 3000 5000р
# 5000 10000р
# 10000 20000р
# 20.000р +
# самые желанный книга
# dyson
# шмотошная
# лёшик
# экстрас
# консуллер
# ибусики
# бытовушка
#
#
#
# Label 3: 6 wish lists
# приоритетный
# важный
# масштабный
# второстепенный
# актуальный
# дорого интересный
#
#
#
# Label 4: 22 wish lists
# шмотки
# одежда
# косметика
# одежда обувь
# обувь
# гардероб
# косметика парфюмерия
# вкусности
# парфюмерия
# косметика уход
# обувь аксессуар
# мебель
# посуда
# верхний одежда
# спортивный одежда
# обувь одежда
# косметика тп
# макияж мириться
# одежда аксессуар
# косметика дух
# макияж
# уход косметика
#
#
#
# Label 5: 4 wish lists
# художественный литература
# публичный
# рождественский
# семейный
#
#
#
# Label 6: 7 wish lists
# отдых
# уход
# полезный ништяки
# полезный
# близкий
# уход здоровье
# самый
#
#
#
# Label 7: 5 wish lists
# мама
# малышка
# кукла фигурка
# девочка
# кукла
#
#
#
# Label 8: 4 wish lists
# красота здоровье
# косметический средство
# здоровье бабушка
# кофе штука
#
#
#
# Label 9: 9 wish lists
# красота дух
# дух
# красота уход
# вещь дом
# мечта королева
# больший мечта
# заветный мечта
# салон красота
# красота культура
#
#
#
# Label 10: 7 wish lists
# ежедневник
# ручка
# умный книжка
# тросточка
# вещица
# брелок
# игрушка
#
#
#
# Label 11: 9 wish lists
# девушка
# маша
# сестра
# дочь
# катенька
# ксюша
# варенька
# варя
# ведьма
#
#
#
# Label 12: 21 wish lists
# 23 февраль
# 30 год
# желанный
# 8 март
# мия 2 год
# день ​​рождения
# подписка
# 20 год привет
# г дневный
# зима 21/22
# зима 2022
# предпочитать следующий
# новий год
# 2022 год
# важный праздник
# праздник повод
# почвенные день
# 8 март дн день
# почва праздник
# 12 февраль
# день влюблённых
#
#
#
# Label 13: 2 wish lists
# кроссовки
# футболка
#
#
#
# Label 14: 13 wish lists
# неть
# кухня
# технос
# потрясать
# премиум
# предпочитать 2025
# вещизм
# носить
# яркость
# окуривать
# art relax
# губа
# фг
#
#
#
# Label 15: 7 wish lists
# взрослый
# желаемый
# жильё
# нормальный приоритет
# должный
# серьёзный подход
# доступный
#
#
#
# Label 16: 3 wish lists
# чемодан
# пропустить whoad
# ресторан
#
#
#
# Label 17: 11 wish lists
# книга
# чтение
# порадовать заслуга
# книга книга
# образ жизнь
# книга канцелярия
# впечатление
# творчество
# книга сын
# творчество развитие
# новый опыт впечатление
#
#
#
# Label 18: 4 wish lists
# книжный
# бассейн
# балкон
# интерьер
#
#
#
# Label 19: 5 wish lists
# украшение
# аксессуар
# украшение аксессуар
# сумка аксессуар
# аксессуар украшение
#
#
#
# Label 20: 10 wish lists
# красивый
# маникюр
# высокий приоритет
# прекрасный жизнь
# шоб прекрасный
# пушистый
# домик
# маленький радость
# уютный дом
# маленький хотелки
#
#
#
# Label 21: 3 wish lists
# квартира
# новый квартира
# идеальный квартира
#
#
#
# Label 22: 2 wish lists
# линейный
# вспомогательный
#
#
#
# Label 23: 3 wish lists
# путешествие
# инкогнито
# путешествовать
#
#
#
# Label 24: 6 wish lists
# еда
# здоровье
# курить
# чай
# алкоголь
# еда напиток
#
#
#
# Label 25: 3 wish lists
# пижама
# помада
# татуировка
#
#
#
# Label 26: 2 wish lists
# курс
# отметка
#
#
#
# Label 27: 2 wish lists
# секретный
# детектив
#
#
#
# Label 28: 2 wish lists
# плечо
# рюкзак
#
#
#
# Label 29: 2 wish lists
# частный
# продавец
#
#
#
# Label 30: 3 wish lists
# гитара
# инструмент
# скрипка
#
#
#
# Label 31: 10 wish lists
# машина
# хата
# построить
# авто
# дача
# легковой автомобиль
# бытовой
# машинка мотоцикл
# велосипед
# крутой
#
#
#
# Label 32: 7 wish lists
# подарочный сертификат
# буклет
# сноуборд
# сертификат
# наушник
# кататься сноуборд
# яки
#
#
#
# Label 33: 3 wish lists
# личный
# кабинет
# личный приличный
#
#
#
# Label 34: 3 wish lists
# растение
# масло
# рецепт
#
#
#
# Label 35: 3 wish lists
# ромочка
# пупсик
# сыночек
#
#
#
# Label 36: 2 wish lists
# полить
# лук
#
#
#
# Label 37: 2 wish lists
# почитать
# писать
#
#
#
# Label 38: 8 wish lists
# нереальный
# прихоть
# прихоть дешёвый
# сокровенный
# сложный сложный
# худ материал
# ритуальный предмет
# мероприятие
#
#
#
# Label 39: 6 wish lists
# арт
# фотосессия фотограф
# фотограф
# свадьба
# любимый
# внешность
#
#
#
# Label 40: 2 wish lists
# лаванда
# древесина
#
#
#
# Label 41: 1 wish lists
# мыло
#
#
#
# Label 42: 9 wish lists
# ребёнок
# ps games
# гнёздышко
# кривой
# санта
# d r.
# ночка the cat
# ребёнок 2 годик
# внутренний ребёнок
#
#
#
# Label 43: 2 wish lists
# очки оправа
# лист свадьба
#
#
#
# Label 44: 6 wish lists
# материальный
# прочий стаф
# общий
# общий ксю
# нематериальный
# разный приколюхи
#
#
#
# Label 45: 3 wish lists
# хобби
# увлечение
# душа хобби
#
#
#
# Label 46: 4 wish lists
# образование
# обучение
# образование развитие
# обучение 2022
#
#
#
# Label 47: 1 wish lists
# apple
#
#
#
# Label 48: 49 wish lists
# аксессуар жизнь
# свеча свет душа
# влейте немного жизнь
# кошачий дом
# приятный мелочь
# муж подсказка
# время доктор
# просто хотелки
# терять вкус жизнь
# нибудь
# штука
# комп рабочий место
# снова 21
# штука рисование
# низкий приоритет
# нужный больше
# парень 18
# s взять 15
# под сомнение
# мелочь
# конец 22 год
# новый 2022
# 100 новый вещь попробовать вместе
# пахнуть хорошо
# больше нравиться
# богатый будущее
# дать бог
# подойти тайный санты
# стиль жизнь
# сильно необходимый
# малыш
# без повод
# куда поехать
# приятный иметь
# должный иметь
# дом аксессуар
# приятный бюджетно
# 100 вариант
# мечтать масштабно
# полезный дом
# шоб забыть дороговатый
# друг родственник
# зеркало
# разный случай
# беспроигрышный вариант
# никто мучить
# 1 р месяц
# дом ритуал
# продавать без повод
#
#
#
# Label 49: 8 wish lists
# ник
# доктор
# детка
# шон
# настроение
# мужчина
# рад
# кросс
#
#
#
# Label 50: 3 wish lists
# свеча
# шарф
# софы
#
#
#
# Label 51: 11 wish lists
# надин
# пандора
# мими
# карин
# доминик
# анджелина
# кристоф
# амелия
# дитя
# мики
# эва
#
#
#
# Label 52: 6 wish lists
# домашний утварь
# домашний комфорт
# телефон
# домашний
# домашний улучшение
# домашний уют
#
#
#
# Label 53: 7 wish lists
# место событие
# день
# b день
# следующий
# праздник
# течение год
# год
#
#
#
# Label 54: 49 wish lists
# фото
# лего
# сумка
# игрушечки
# вещичка
# штучки
# шмот
# hb
# саморазвитие
# декор
# кисточка
# приятность
# повод
# побрякушка
# релаксация
# кс
# дух косметика процедура
# кроков
# ozon
# amazon
# ввв
# сладость
# набор турист
# мясистый
# бады
# постер фигурка тд
# клавир
# одёжка
# кожа
# девайс
# команда
# проза
# набор ультразвуковой чистка
# учреждать
# люкс
# оздоровительный
# hyundai tucson
# фотоплёнка картриджи
# антиутопия
# ванная
# запасть
# домен
# youu shop
# инвестиция
# съёмка
# влетит копеечка
# ролл фитнес
# спальня
# мышь хотелки
#
#
#
# Label 55: 1 wish lists
# покушать
#
#
#
# Label 56: 2 wish lists
# кулинария
# эзотерика
#
#
#
# Label 57: 5 wish lists
# цветок вместо
# браслет reflexions
# серьга
# цветок
# кольцо
#
#
#
# Label 58: 2 wish lists
# поездка
# каникулы
#
#
#
# Label 59: 6 wish lists
# новоселье
# случай новоселье
# рождество 2021
# рождество друг
# рождество
# счастливый bd
#
#
#
# Label 60: 7 wish lists
# детский
# ювелирный изделие
# детский душ
# мини
# изделие
# безумно шикарный
# филиал
#
#
#
# Label 61: 10 wish lists
# дорогой хотелки
# котик
# митрополит
# федя
# слишком дорогой дарить
# дорогой
# папа
# дорогой дедушка мороз
# еврей
# санкт петербург
#
#
#
# Label 62: 2 wish lists
# коробка
# платформа
#
#
#
# Label 63: 4 wish lists
# видео
# пластинка диски кассета
# пластинка
# контент
#
#
#
# Label 64: 3 wish lists
# крупный
# крупный звездолёт
# финансовый капитал
#
#
#
# Label 65: 2 wish lists
# подход
# тон
#
#
#
# Label 66: 6 wish lists
# март
# осень
# лето
# январь
# февраль
# май
#
#
#
# Label 67: 7 wish lists
# подбрасывать вверх
# двое
# концерт
# вертикальный магазин
# упражняться
# сумка рюкзак
# магазин целое
#
#
#
# Label 68: 9 wish lists
# работа
# творчество работа
# медитация
# основной
# место действие
# про работа
# ежедневно
# развитие
# эмоция
#
#
#
# Label 69: 1 wish lists
# стиль
#
#
#
# Label 70: 2 wish lists
# родитель
# сафон любимчик
#
#
#
# Label 71: 1 wish lists
# родным
#
#
#
# Label 72: 1 wish lists
# фед
#
#
#
# Label 73: 2 wish lists
# лечение
# порок
#
#
#
# Label 74: 1 wish lists
# программа
#
#
#
# Label 75: 1 wish lists
# карта
#
#
#
# Label 76: 5 wish lists
# студия дом
# впечатление обучение
# тасина библиотека
# совет влади
# библиотека
#
#
#
# Label 77: 2 wish lists
# серёжи
# вити
#
#
#
# Label 78: 1 wish lists
# парфюм
#
#
#
# Label 79: 1 wish lists
# вкусный
#
#
#
# Label 80: 7 wish lists
# 1000 рубль
# 2000 рубль
# 3000 рубль
# 100к рубль
# 25к рубль
# 10к рубль
# 6к рубль
#
#
#
# Label 81: 18 wish lists
# гаджет
# дёма
# винил
# хочю
# тёма
# бекс
# василёк
# юбиляр
# рррр
# котёнок
# дэйвид
# плиз
# серьёзно
# анти далл
# лёши
# тём
# хоум
# джи
#
#
#
# Label 82: 2 wish lists
# опыт
# власть
#
#
#
# Label 83: 3 wish lists
# волос
# очки
# штаны
#
#
#
# Label 84: 2 wish lists
# сочинительство
# искусство
#
#
#
# Label 85: 3 wish lists
# красота
# вещь
# мечта
#
#
#
# Label 86: 8 wish lists
# игра
# спорт
# альпинизм
# развлечение
# настольный игра
# спорт активность
# спорт хуёрт
# спорт питание
#
#
#
# Label 87: 5 wish lists
# техника
# домашний техника
# бытовой техника
# техника электроника прибор
# техника мебель
#
#
#
# Label 88: 4 wish lists
# поход
# нижний бельё
# luara крым
# поход путешествие
#
#
#
# Label 89: 2 wish lists
# также
# т д м
#
#
#
# Label 90: 1 wish lists
# средний
#
#
#
# Label 91: 3 wish lists
# бельё
# бельишко
# постельный бельё
#
#
#
# Label 92: 2 wish lists
# молодёжь
# лишать
#
#
#
# Label 93: 6 wish lists
# дарить
# книга комикс
# книга бумажный
# книга курс
# фотография
# комикс
#
#
#
# Label 94: 2 wish lists
# моделирование
# базовый
#
#
#
# Label 95: 2 wish lists
# творческий
# девчачий
#
#
#
# Label 96: 1 wish lists
# музыка
#
#
#
# Label 97: 1 wish lists
# бьюти
#
#
#
# Label 98: 6 wish lists
# старость
# ура старость
# уход тело
# ааааа
# сука
# тело
#
#
#
# Label 99: 1 wish lists
# процедура
